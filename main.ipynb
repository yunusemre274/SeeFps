# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("main_merged.csv")

# %%
df.head()
# Out:
#                   cpuname  cpunumberofcores  cpunumberofthreads  cpubaseclock  \
# 0  b'Intel Core i9-9900K'               8.0                16.0         100.0
# 1  b'Intel Core i7-9700K'               8.0                 8.0         100.0
# 2  b'Intel Core i7-8700K'               6.0                12.0         100.0
# 3  b'Intel Core i7-7700K'               4.0                 8.0         100.0
# 4  b'Intel Core i5-9400F'               6.0                 6.0         100.0
#
#    cpucachel1  cpucachel2  cpucachel3  cpudiesize  cpufrequency  \
# 0       512.0      2048.0        16.0         NaN        3600.0
# 1       512.0      2048.0        12.0         NaN        3600.0
# 2       384.0      1536.0        12.0         NaN        3700.0
# 3       256.0      1024.0         8.0         NaN        4200.0
# 4       384.0      1536.0         9.0         NaN        2900.0
#
#    cpumultiplier  ... top_cores  render_config_shading_units  \
# 0           36.0  ...       NaN                          NaN
# 1           36.0  ...       NaN                          NaN
# 2           37.0  ...       NaN                          NaN
# 3           42.0  ...       NaN                          NaN
# 4           29.0  ...       NaN                          NaN
#
#    render_config_compute_units  render_config_l2_cache  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#    theoretical_performance_fp32_(float) theoretical_performance_fp64_(double)  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#   render_config_l1_cache  theoretical_performance_fp16_(half)  \
# 0                    NaN                                  NaN
# 1                    NaN                                  NaN
# 2                    NaN                                  NaN
# 3                    NaN                                  NaN
# 4                    NaN                                  NaN
#
#    render_config_sm_count  graphics_features_cuda
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
# [5 rows x 113 columns]

# %%
print(df.columns.tolist())
# Out:
# ['cpuname', 'cpunumberofcores', 'cpunumberofthreads', 'cpubaseclock', 'cpucachel1', 'cpucachel2', 'cpucachel3', 'cpudiesize', 'cpufrequency', 'cpumultiplier', 'cpumultiplierunlocked', 'cpuprocesssize', 'cputdp', 'cpunumberoftransistors', 'cputurboclock', 'gpuname', 'gpuarchitecture', 'gpubandwidth', 'gpubaseclock', 'gpuboostclock', 'gpubus_interface', 'gpunumberofcomputeunits', 'gpudiesize', 'gpudirectx', 'gpufp32performance', 'gpumemorybus', 'gpumemorysize', 'gpumemorytype', 'gpuopencl', 'gpuopengl', 'gpupixelrate', 'gpuprocesssize', 'gpunumberofrops', 'gpushadermodel', 'gpunumberofshadingunits', 'gpunumberoftmus', 'gputexturerate', 'gpunumberoftransistors', 'gpuvulkan', 'gamename', 'gameresolution', 'gamesetting', 'fps', 'brand', 'name', 'top_graphics_processor', 'top_pixel_shaders', 'top_tmus', 'top_rops', 'top_memory_size', 'top_memory_type', 'top_bus_width', 'graphics_processor_gpu_name', 'graphics_processor_architecture', 'graphics_processor_process_size', 'graphics_processor_transistors', 'graphics_processor_die_size', 'graphics_card_release_date', 'graphics_card_generation', 'graphics_card_successor', 'graphics_card_production', 'graphics_card_bus_interface', 'clock_speeds_gpu_clock', 'clock_speeds_memory_clock', 'memory_memory_size', 'memory_memory_type', 'memory_memory_bus', 'memory_bandwidth', 'render_config_pixel_shaders', 'render_config_vertex_shaders', 'render_config_tmus', 'render_config_rops', 'theoretical_performance_pixel_rate', 'theoretical_performance_texture_rate', 'board_design_slot_width', 'board_design_tdp', 'board_design_suggested_psu', 'board_design_outputs', 'board_design_board_number', 'graphics_features_directx', 'graphics_features_opengl', 'graphics_features_opencl', 'graphics_features_vulkan', 'source_file', 'graphics_processor_foundry', 'graphics_card_predecessor', 'recommended_resolutions', 'graphics_card_launch_price', 'board_design_length', 'graphics_processor_gpu_variant', 'board_design_power_connectors', 'graphics_processor_density', 'graphics_card_reviews', 'mobile_graphics_release_date', 'mobile_graphics_generation', 'mobile_graphics_production', 'mobile_graphics_bus_interface', 'graphics_processor_chip_package', 'mobile_graphics_successor', 'mobile_graphics_predecessor', 'clock_speeds_base_clock', 'clock_speeds_boost_clock', 'graphics_features_shader_model', 'top_cores', 'render_config_shading_units', 'render_config_compute_units', 'render_config_l2_cache', 'theoretical_performance_fp32_(float)', 'theoretical_performance_fp64_(double)', 'render_config_l1_cache', 'theoretical_performance_fp16_(half)', 'render_config_sm_count', 'graphics_features_cuda']

# %%
null_cols=[]

for col in df.columns:
    if (df[col].isnull().sum() / len(df)) * 100 > 80:
        null_cols.append(col)

# %%
df=df.drop(columns=null_cols)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24624 entries, 0 to 24623
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cpuname                  24624 non-null  str
#  1   cpunumberofcores         24624 non-null  float64
#  2   cpunumberofthreads       24624 non-null  float64
#  3   cpubaseclock             24624 non-null  float64
#  4   cpucachel1               24624 non-null  float64
#  5   cpucachel2               24624 non-null  float64
#  6   cpucachel3               24624 non-null  float64
#  7   cpudiesize               11664 non-null  float64
#  8   cpufrequency             24624 non-null  float64
#  9   cpumultiplier            24624 non-null  float64
#  10  cpumultiplierunlocked    24624 non-null  str
#  11  cpuprocesssize           24624 non-null  float64
#  12  cputdp                   24624 non-null  float64
#  13  cpunumberoftransistors   11664 non-null  float64
#  14  cputurboclock            24624 non-null  float64
#  15  gpuname                  24624 non-null  str
#  16  gpuarchitecture          24624 non-null  str
#  17  gpubandwidth             24624 non-null  float64
#  18  gpubaseclock             24624 non-null  float64
#  19  gpuboostclock            24624 non-null  float64
#  20  gpubus_interface         24624 non-null  str
#  21  gpunumberofcomputeunits  5472 non-null   float64
#  22  gpudiesize               24624 non-null  float64
#  23  gpudirectx               24624 non-null  str
#  24  gpufp32performance       24624 non-null  float64
#  25  gpumemorybus             24624 non-null  float64
#  26  gpumemorysize            24624 non-null  float64
#  27  gpumemorytype            24624 non-null  str
#  28  gpuopencl                24624 non-null  str
#  29  gpuopengl                24624 non-null  str
#  30  gpupixelrate             24624 non-null  float64
#  31  gpuprocesssize           24624 non-null  float64
#  32  gpunumberofrops          24624 non-null  float64
#  33  gpushadermodel           24624 non-null  str
#  34  gpunumberofshadingunits  24624 non-null  float64
#  35  gpunumberoftmus          24624 non-null  float64
#  36  gputexturerate           24624 non-null  float64
#  37  gpunumberoftransistors   24624 non-null  float64
#  38  gpuvulkan                24624 non-null  str
#  39  gamename                 24624 non-null  str
#  40  gameresolution           24624 non-null  float64
#  41  gamesetting              24624 non-null  str
#  42  fps                      24624 non-null  float64
# dtypes: float64(30), str(13)
# memory usage: 8.1 MB

# %%
catCols=df.select_dtypes(include="object").columns.tolist()
numCols=df.select_dtypes(include=np.number).columns.tolist()

numCols
# Out:
# /var/folders/4w/3l5_jnq16853t_kj_7266xhc0000gn/T/ipykernel_11685/2246997704.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   catCols=df.select_dtypes(include="object").columns.tolist()
# ['cpunumberofcores',
#  'cpunumberofthreads',
#  'cpubaseclock',
#  'cpucachel1',
#  'cpucachel2',
#  'cpucachel3',
#  'cpudiesize',
#  'cpufrequency',
#  'cpumultiplier',
#  'cpuprocesssize',
#  'cputdp',
#  'cpunumberoftransistors',
#  'cputurboclock',
#  'gpubandwidth',
#  'gpubaseclock',
#  'gpuboostclock',
#  'gpunumberofcomputeunits',
#  'gpudiesize',
#  'gpufp32performance',
#  'gpumemorybus',
#  'gpumemorysize',
#  'gpupixelrate',
#  'gpuprocesssize',
#  'gpunumberofrops',
#  'gpunumberofshadingunits',
#  'gpunumberoftmus',
#  'gputexturerate',
#  'gpunumberoftransistors',
#  'gameresolution',
#  'fps']

# %%
for i in catCols:
    print(f"Column: {i}, unique values: {df[i].unique().tolist()}")
# Out:
# Column: cpuname, unique values: ["b'Intel Core i9-9900K'", "b'Intel Core i7-9700K'", "b'Intel Core i7-8700K'", "b'Intel Core i7-7700K'", "b'Intel Core i5-9400F'", "b'Intel Core i5-8600K'", "b'Intel Core i5-8400'", "b'Intel Core i5-7600K'", "b'Intel Core i5-7500'", "b'Intel Core i3-7100'", "b'AMD Ryzen 9 3900X'", "b'AMD Ryzen 7 3800X'", "b'AMD Ryzen 7 3700X'", "b'AMD Ryzen 5 3600X'", "b'AMD Ryzen 5 3600'", "b'AMD Ryzen 5 2600X'", "b'AMD Ryzen 5 1600X'", "b'AMD Ryzen 5 2600'", "b'AMD Ryzen 7 1700X'"]
# Column: cpumultiplierunlocked, unique values: ["b'1'", "b'0'"]
# Column: gpuname, unique values: ["b'nvidia geforce rtx 2080 ti'", "b'nvidia geforce rtx 2080'", "b'nvidia geforce gtx 1080 ti'", "b'nvidia geforce gtx titan x'", "b'nvidia geforce rtx 2070 super'", "b'nvidia geforce rtx 2070'", "b'nvidia geforce gtx 1080 11gbps'", "b'nvidia geforce rtx 2060 super'", "b'nvidia geforce rtx 2060'", "b'nvidia geforce gtx 1070 ti'", "b'nvidia geforce gtx 1070 gddr5x'", "b'nvidia geforce gtx 1660 ti'", "b'nvidia geforce gtx 1660 super'", "b'nvidia geforce gtx 980 ti'", "b'nvidia geforce gtx 1660'", "b'nvidia geforce gtx 1060 6 gb gddr5x'", "b'nvidia geforce gtx 980'", "b'nvidia geforce gtx 1060 5 gb'", "b'nvidia geforce gtx 970'", "b'nvidia geforce gtx 1050 ti'", "b'nvidia geforce gtx 1050 3 gb'", "b'amd radeon rx 5700 xt'", "b'amd radeon rx 5700'", "b'amd radeon pro vega 64'", "b'amd radeon rx 590'", "b'amd radeon rx 580'", "b'amd radeon rx 570'"]
# Column: gpuarchitecture, unique values: ["b'Turing'", "b'Pascal'", "b'Maxwell 2.0'", "b'RDNA 1.0'", "b'GCN 5.0'", "b'GCN 4.0'"]
# Column: gpubus_interface, unique values: ["b'PCIe 3.0 x16'", "b'PCIe 4.0 x16'"]
# Column: gpudirectx, unique values: ["b'12 Ultimate'", "b'12'"]
# Column: gpumemorytype, unique values: ["b'GDDR6'", "b'GDDR5X'", "b'GDDR5'", "b'HBM2'"]
# Column: gpuopencl, unique values: ["b'2'", "b'1.2'"]
# Column: gpuopengl, unique values: ["b'4.6'"]
# Column: gpushadermodel, unique values: ["b'6.5'", "b'6.4'"]
# Column: gpuvulkan, unique values: ["b'1.2.131'", "b'1.1.126'", "b'1.1.125'"]
# Column: gamename, unique values: ["b'callOfDutyWW2'", "b'fortnite'", "b'pathOfExile'", "b'destiny2'", "b'radicalHeights'", "b'leagueOfLegends'", "b'overwatch'", "b'playerUnknownsBattlegrounds'", "b'dota2'", "b'counterStrikeGlobalOffensive'", "b'seaOfThieves'", "b'apexLegends'", "b'frostpunk'", "b'totalWar3Kingdoms'", "b'worldOfTanks'", "b'battlefield4'", "b'warframe'", "b'airMechStrike'", "b'battletech'", "b'farCry5'", "b'starcraft2'", "b'rainbowSixSiege'", "b'grandTheftAuto5'", "b'aWayOut'"]
# Column: gamesetting, unique values: ["b'med'", "b'max'"]

# %%
df['cpu_threads_per_core'] = df['cpunumberofthreads'] / (df['cpunumberofcores'] + 1)
df['cpu_total_cache'] = df['cpucachel1'] + df['cpucachel2'] + df['cpucachel3']
df['gpu_compute_proxy'] = df['gpunumberofcomputeunits'] * df['gpuboostclock']
df['gpu_bandwidth_per_compute_unit'] = df['gpubandwidth'] / (df['gpunumberofcomputeunits'] + 1)
df['bottleneck_ratio_cpu_gpu'] = df['cpunumberofcores'] / (df['gpunumberofcomputeunits'] + 1)
df['bottleneck_ratio_memory_gpu'] = df['gpumemorysize'] / (df['gpumemorysize'] + 1)
df['bottleneck_ratio_cpu_memory'] = df['cpunumberofcores'] / (df['gpumemorysize'] + 1)
df['performance_per_tdp'] = df['gpufp32performance'] / (df['cputdp'] + 1)
df['cpu_gpu_frequency_ratio'] = df['cpufrequency'] / (df['gpuboostclock'] + 1)
df['memory_bandwidth_efficiency'] = df['gpubandwidth'] / (df['gpumemorysize'] + 1)
df['core_to_memory_ratio'] = df['gpunumberofcomputeunits'] / (df['gpumemorysize'] + 1)
df['cache_efficiency'] = df['cpu_total_cache'] / (df['cpunumberofcores'] + 1)
df['cpu_performance_score'] = (df['cpunumberofcores'] * df['cpubaseclock']) / (df['cpuprocesssize'] + 1)
df['gpu_performance_score'] = (df['gpunumberofcomputeunits'] * df['gpuboostclock']) /(df['gpuprocesssize'] + 1)

print("Feature engineering completed successfully")
print("New engineered features created:")
print("cpu_threads_per_core")
print("cpu_total_cache")
print("gpu_compute_proxy")
print("gpu_bandwidth_per_compute_unit")
print("bottleneck_ratio_cpu_gpu")
print("bottleneck_ratio_memory_gpu")
print("bottleneck_ratio_cpu_memory")
print("performance_per_tdp")
print("cpu_gpu_frequency_ratio")
print("memory_bandwidth_efficiency")
print("core_to_memory_ratio")
print("cache_efficiency")
print("cpu_performance_score")
print("gpu_performance_score")
# Out:
# Feature engineering completed successfully
# New engineered features created:
# cpu_threads_per_core
# cpu_total_cache
# gpu_compute_proxy
# gpu_bandwidth_per_compute_unit
# bottleneck_ratio_cpu_gpu
# bottleneck_ratio_memory_gpu
# bottleneck_ratio_cpu_memory
# performance_per_tdp
# cpu_gpu_frequency_ratio
# memory_bandwidth_efficiency
# core_to_memory_ratio
# cache_efficiency
# cpu_performance_score
# gpu_performance_score

# %%
numCols=df.select_dtypes(include=np.number).columns.tolist()
numCols
# Out:
# ['cpunumberofcores',
#  'cpunumberofthreads',
#  'cpubaseclock',
#  'cpucachel1',
#  'cpucachel2',
#  'cpucachel3',
#  'cpudiesize',
#  'cpufrequency',
#  'cpumultiplier',
#  'cpuprocesssize',
#  'cputdp',
#  'cpunumberoftransistors',
#  'cputurboclock',
#  'gpubandwidth',
#  'gpubaseclock',
#  'gpuboostclock',
#  'gpunumberofcomputeunits',
#  'gpudiesize',
#  'gpufp32performance',
#  'gpumemorybus',
#  'gpumemorysize',
#  'gpupixelrate',
#  'gpuprocesssize',
#  'gpunumberofrops',
#  'gpunumberofshadingunits',
#  'gpunumberoftmus',
#  'gputexturerate',
#  'gpunumberoftransistors',
#  'gameresolution',
#  'fps',
#  'cpu_threads_per_core',
#  'cpu_total_cache',
#  'gpu_compute_proxy',
#  'gpu_bandwidth_per_compute_unit',
#  'bottleneck_ratio_cpu_gpu',
#  'bottleneck_ratio_memory_gpu',
#  'bottleneck_ratio_cpu_memory',
#  'performance_per_tdp',
#  'cpu_gpu_frequency_ratio',
#  'memory_bandwidth_efficiency',
#  'core_to_memory_ratio',
#  'cache_efficiency',
#  'cpu_performance_score',
#  'gpu_performance_score']

# %%
correlation_matrix = df[numCols].corr()
high_corr_pairs = {}
threshold = 0.95
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr_value = correlation_matrix.iloc[i, j]
        if abs(corr_value) >= threshold:
            feature1 = correlation_matrix.columns[i]
            feature2 = correlation_matrix.columns[j]
            high_corr_pairs[(feature1, feature2)] = corr_value
print("High correlation pairs (threshold >= 0.85):")
for pair, correlation in high_corr_pairs.items():
    print(f"{pair[0]} - {pair[1]}: {correlation:.3f}")
print("\nDictionary of high correlation pairs:")
print(high_corr_pairs)
# Out:
# High correlation pairs (threshold >= 0.85):
# cpucachel1 - cpucachel2: 0.988
# cpucachel1 - cpu_total_cache: 0.991
# cpucachel2 - cpu_total_cache: 1.000
# cpucachel3 - cpu_performance_score: 0.969
# cpudiesize - cpuprocesssize: 0.976
# cpudiesize - cpunumberoftransistors: 1.000
# cpufrequency - cpumultiplier: 1.000
# cpuprocesssize - cpunumberoftransistors: 0.976
# gpubaseclock - gpuboostclock: 0.960
# gpunumberofcomputeunits - gpudiesize: 0.985
# gpunumberofcomputeunits - gpumemorybus: 0.976
# gpunumberofcomputeunits - gpumemorysize: 0.961
# gpunumberofcomputeunits - gpunumberofshadingunits: 1.000
# gpunumberofcomputeunits - gpunumberoftmus: 1.000
# gpufp32performance - gputexturerate: 1.000
# gpufp32performance - gpu_compute_proxy: 1.000
# gpupixelrate - gpu_performance_score: 0.982
# gpuprocesssize - gpu_bandwidth_per_compute_unit: -0.968
# gpunumberofshadingunits - gpunumberoftmus: 1.000
# gputexturerate - gpu_compute_proxy: 1.000
# bottleneck_ratio_memory_gpu - core_to_memory_ratio: -0.961
#
# Dictionary of high correlation pairs:
# {('cpucachel1', 'cpucachel2'): np.float64(0.9879817585645879), ('cpucachel1', 'cpu_total_cache'): np.float64(0.9911998041342849), ('cpucachel2', 'cpu_total_cache'): np.float64(0.9997396394941291), ('cpucachel3', 'cpu_performance_score'): np.float64(0.9694078994543354), ('cpudiesize', 'cpuprocesssize'): np.float64(0.9759000729485368), ('cpudiesize', 'cpunumberoftransistors'): np.float64(1.0), ('cpufrequency', 'cpumultiplier'): np.float64(1.0), ('cpuprocesssize', 'cpunumberoftransistors'): np.float64(0.9759000729485364), ('gpubaseclock', 'gpuboostclock'): np.float64(0.9598788673922121), ('gpunumberofcomputeunits', 'gpudiesize'): np.float64(0.9849096227345454), ('gpunumberofcomputeunits', 'gpumemorybus'): np.float64(0.9763746171404255), ('gpunumberofcomputeunits', 'gpumemorysize'): np.float64(0.9614186262267694), ('gpunumberofcomputeunits', 'gpunumberofshadingunits'): np.float64(1.0), ('gpunumberofcomputeunits', 'gpunumberoftmus'): np.float64(1.0), ('gpufp32performance', 'gputexturerate'): np.float64(0.9999999290201337), ('gpufp32performance', 'gpu_compute_proxy'): np.float64(0.9999999929784311), ('gpupixelrate', 'gpu_performance_score'): np.float64(0.9820893685187869), ('gpuprocesssize', 'gpu_bandwidth_per_compute_unit'): np.float64(-0.9679503429676695), ('gpunumberofshadingunits', 'gpunumberoftmus'): np.float64(1.0), ('gputexturerate', 'gpu_compute_proxy'): np.float64(0.999999940444687), ('bottleneck_ratio_memory_gpu', 'core_to_memory_ratio'): np.float64(-0.9613941479949563)}

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedKFold
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression,RidgeCV,LassoCV,ElasticNetCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler,OrdinalEncoder,LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from lazypredict.Supervised import LazyRegressor
from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
X=df.drop(columns=['fps','gpuname','cpuname'])
y=df['fps']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np

print("1. Pipeline'lar (Boru Hatları) Hazırlanıyor...")

# Sayısal Kolonlar İçin: Önce boşlukları medyan ile doldur, sonra StandardScaler uygula
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Ordinal Kolonlar İçin: Önce boşlukları en çok tekrar edenle doldur, sonra Ordinal Encoder uygula
ord_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ord', OrdinalEncoder(categories=ordinal_categories, handle_unknown='use_encoded_value', unknown_value=-1))
])

# One-Hot Kolonlar İçin: Önce boşlukları en çok tekrar edenle doldur, sonra OneHot Encoder uygula
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('cat', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
])

print("2. ColumnTransformer Güncelleniyor...")
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_pipeline, numeric_cols),
        ('ord', ord_pipeline, ordinal_cols),
        ('cat', cat_pipeline, onehot_cols)
    ],
    remainder='passthrough'
)

print("3. Veriler Eksiksiz Olarak Dolduruluyor ve Dönüştürülüyor...")
# Yeniden X_train ve X_test'i oluşturuyoruz (Artık içinde 1 tane bile NaN yok)
X_train_processed_array = preprocessor.fit_transform(X_train)
X_test_processed_array = preprocessor.transform(X_test)

# Sütun isimlerini yeniden çekip DataFrame'e çevirme kısmı:
# (Pipeline kullandığımız için isim çekme mantığı biraz değişti)
yeni_kolon_isimleri = preprocessor.get_feature_names_out()
yeni_kolon_isimleri = [isim.split('__')[-1] for isim in yeni_kolon_isimleri] 

X_train_processed = pd.DataFrame(X_train_processed_array, columns=yeni_kolon_isimleri, index=X_train.index)
X_test_processed = pd.DataFrame(X_test_processed_array, columns=yeni_kolon_isimleri, index=X_test.index)

# cpumultiplierunlocked eğer içinde NaN barındırıyorsa onu da 0 ile dolduralım (remainder passthrough olduğu için sona kaldı)
if 'cpumultiplierunlocked' in X_train_processed.columns:
    X_train_processed['cpumultiplierunlocked'] = X_train_processed['cpumultiplierunlocked'].fillna(0)
    X_test_processed['cpumultiplierunlocked'] = X_test_processed['cpumultiplierunlocked'].fillna(0)

print("\nİŞLEM BAŞARILI! Veri setinde hiç NaN kalmadı. Tüm modeller çalışmaya hazır.")
# Out:
# 1. Pipeline'lar (Boru Hatları) Hazırlanıyor...
# 2. ColumnTransformer Güncelleniyor...
# 3. Veriler Eksiksiz Olarak Dolduruluyor ve Dönüştürülüyor...
#
# İŞLEM BAŞARILI! Veri setinde hiç NaN kalmadı. Tüm modeller çalışmaya hazır.

# %%
X_train_processed.head()
# Out:
#        cpunumberofcores  cpunumberofthreads  cpubaseclock  cpucachel1  \
# 18966         -0.145352           -0.924648           0.0   -0.555829
# 24087         -0.145352            0.227400           0.0    0.265798
# 23000          2.736191            2.531494           0.0    2.730678
# 14512         -0.145352            0.227400           0.0    0.265798
# 16671         -1.105867           -1.308663           0.0   -1.103580
#
#        cpucachel2  cpucachel3  cpudiesize  cpufrequency  cpumultiplier  \
# 18966   -0.687386   -0.643007   -0.515754     -2.175012      -2.175012
# 24087    0.410577    0.973491   -0.515754      0.031215       0.031215
# 23000    2.606504    3.222531   -0.515754      0.661566       0.661566
# 14512    0.410577   -0.151029    1.938907      0.031215       0.031215
# 16671   -1.053374   -0.853854   -0.515754     -0.599136      -0.599136
#
#        cpuprocesssize  ...  gamename_worldOfTanks  gpuarchitecture_GCN 5.0  \
# 18966        0.676619  ...                    0.0                      0.0
# 24087       -1.648641  ...                    0.0                      0.0
# 23000       -1.648641  ...                    0.0                      0.0
# 14512        0.012259  ...                    0.0                      0.0
# 16671        0.676619  ...                    0.0                      0.0
#
#        gpuarchitecture_Maxwell 2.0  gpuarchitecture_Pascal  \
# 18966                          0.0                     0.0
# 24087                          0.0                     0.0
# 23000                          0.0                     0.0
# 14512                          0.0                     0.0
# 16671                          1.0                     0.0
#
#        gpuarchitecture_RDNA 1.0  gpuarchitecture_Turing  gpumemorytype_GDDR5X  \
# 18966                       0.0                     0.0                   0.0
# 24087                       0.0                     0.0                   0.0
# 23000                       1.0                     0.0                   0.0
# 14512                       0.0                     1.0                   0.0
# 16671                       0.0                     0.0                   0.0
#
#        gpumemorytype_GDDR6  gpumemorytype_HBM2  cpumultiplierunlocked
# 18966                  0.0                 0.0                    0.0
# 24087                  0.0                 0.0                    1.0
# 23000                  1.0                 0.0                    1.0
# 14512                  1.0                 0.0                    1.0
# 16671                  0.0                 0.0                    0.0
#
# [5 rows x 82 columns]

# %%
def show_metrics(model,y_pred):
    r2=r2_score(y_test,y_pred)
    print(f"R2 Score: {r2:.4f}")
    mse=mean_squared_error(y_test,y_pred)
    print(f"MSE: {mse:.4f}")
    mae=mean_absolute_error(y_test,y_pred)
    print(f"MAE: {mae:.4f}")
    rmse=np.sqrt(mse)
    print(f"RMSE: {rmse:.4f}")

# %%
def check_CV(model,threshold=0.3):
    y_train_pred=model.predict(X_train_processed)
    y_test_pred=model.predict(X_test_processed)
    
    train_score=r2_score(y_train,y_train_pred)
    test_score=r2_score(y_test,y_test_pred)
    
    print("Train Score: ",round(train_score,2))
    print("Test Score: ",round(test_score))
    
    if abs(train_score - test_score) > threshold and train_score > test_score:
        print("⚠️ Model is Overfitting")
    elif train_score < 0.6 and test_score < 0.6:
        print("⚠️ Model is Underfitting")
    else:
        print("✅ Model is Fit")

# %%
def run_model(model):
    model.fit(X_train_processed,y_train)
    y_pred=model.predict(X_test_processed)
    check_CV(model)
    show_metrics(model,y_pred)

# %%
models_to_run={
    'RandomForestRegressor':RandomForestRegressor(random_state=21),
    'DecisionTreeRegressor':DecisionTreeRegressor(random_state=21),
    'LinearRegression':LinearRegression(),
    'RidgeCV':RidgeCV(),
    'LassoCV':LassoCV(),
    'ElasticNetCV':ElasticNetCV(),
    'GradientBoostingRegressor':GradientBoostingRegressor(random_state=21),
    'XGBRegressor':XGBRegressor(random_state=21),
    'SVR':SVR()
}

# %%
for model_name,model in models_to_run.items():
    print(f"Model Name: {model_name}")
    run_model(model)
    print("**"*50)
# Out:
# Model Name: RandomForestRegressor
# Train Score:  1.0
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9963
# MSE: 11.3744
# MAE: 2.2255
# RMSE: 3.3726
# ****************************************************************************************************
# Model Name: DecisionTreeRegressor
# Train Score:  1.0
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9931
# MSE: 21.2374
# MAE: 3.0702
# RMSE: 4.6084
# ****************************************************************************************************
# Model Name: LinearRegression
# Train Score:  0.95
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9540
# MSE: 140.7933
# MAE: 7.9147
# RMSE: 11.8656
# ****************************************************************************************************
# Model Name: RidgeCV
# Train Score:  0.95
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9539
# MSE: 140.9975
# MAE: 7.9393
# RMSE: 11.8742
# ****************************************************************************************************
# Model Name: LassoCV
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.914586e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.021257e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.499532e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.664099e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.337654e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.164083e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.293605e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.247613e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.518193e+03, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.853899e+04, tolerance: 4.637e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.603081e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.652085e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.013755e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.205905e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.484498e+04, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.013505e+04, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.813034e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.584811e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.716893e+03, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.832274e+04, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.422679e+04, tolerance: 4.671e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.311939e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.055049e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.125991e+04, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.747244e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260373e+04, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.037641e+04, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.998940e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.298181e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.406719e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.680518e+03, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.485474e+04, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.395451e+04, tolerance: 4.698e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.703208e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.326345e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.926797e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.339604e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.609100e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.862319e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.526357e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.755486e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.826343e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.171846e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.607912e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.863356e+03, tolerance: 4.658e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.302189e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.045260e+04, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.128903e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.179002e+04, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.174763e+04, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.714002e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.046999e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.978428e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.806639e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.777422e+03, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:825: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.083716e+04, tolerance: 4.680e+03
#   model = cd_fast.enet_coordinate_descent_gram(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.687331e+05, tolerance: 5.836e+03
#   model = cd_fast.enet_coordinate_descent(
# Train Score:  0.95
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9515
# MSE: 148.3776
# MAE: 8.3319
# RMSE: 12.1810
# ****************************************************************************************************
# Model Name: ElasticNetCV
# Train Score:  0.87
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.8654
# MSE: 411.7452
# MAE: 14.2135
# RMSE: 20.2915
# ****************************************************************************************************
# Model Name: GradientBoostingRegressor
# Train Score:  0.95
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9520
# MSE: 146.8874
# MAE: 9.8294
# RMSE: 12.1197
# ****************************************************************************************************
# Model Name: XGBRegressor
# Train Score:  1.0
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9976
# MSE: 7.3893
# MAE: 1.8592
# RMSE: 2.7183
# ****************************************************************************************************
# Model Name: SVR
# Train Score:  0.45
# Test Score:  0
# ⚠️ Model is Underfitting
# R2 Score: 0.4253
# MSE: 1758.0784
# MAE: 29.1312
# RMSE: 41.9294
# ****************************************************************************************************

# %%
lazy_reg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = lazy_reg.fit(X_train_processed, X_test_processed, y_train, y_test)
models
# Out:
#                                Adjusted R-Squared     R-Squared          RMSE  \
# Model
# MLPRegressor                         9.996983e-01  9.997034e-01  9.525861e-01
# XGBRegressor                         9.975434e-01  9.975843e-01  2.718332e+00
# HistGradientBoostingRegressor        9.967459e-01  9.968001e-01  3.128596e+00
# ExtraTreesRegressor                  9.967287e-01  9.967832e-01  3.136877e+00
# RandomForestRegressor                9.961799e-01  9.962435e-01  3.389805e+00
# BaggingRegressor                     9.954505e-01  9.955263e-01  3.699290e+00
# DecisionTreeRegressor                9.929730e-01  9.930901e-01  4.597480e+00
# ExtraTreeRegressor                   9.909370e-01  9.910879e-01  5.221225e+00
# PoissonRegressor                     9.819611e-01  9.822615e-01  7.366153e+00
# TransformedTargetRegressor           9.531931e-01  9.539726e-01  1.186564e+01
# LinearRegression                     9.531931e-01  9.539726e-01  1.186564e+01
# RidgeCV                              9.531321e-01  9.539126e-01  1.187336e+01
# BayesianRidge                        9.530346e-01  9.538167e-01  1.188571e+01
# Ridge                                9.530168e-01  9.537992e-01  1.188796e+01
# HuberRegressor                       9.519578e-01  9.527578e-01  1.202119e+01
# LinearSVR                            9.518117e-01  9.526142e-01  1.203946e+01
# SGDRegressor                         9.517185e-01  9.525225e-01  1.205109e+01
# LassoCV                              9.514219e-01  9.522308e-01  1.208806e+01
# GradientBoostingRegressor            9.511671e-01  9.519803e-01  1.211971e+01
# ElasticNetCV                         9.468784e-01  9.477630e-01  1.264072e+01
# LassoLarsCV                          9.452752e-01  9.461865e-01  1.283004e+01
# LassoLarsIC                          9.452752e-01  9.461865e-01  1.283004e+01
# RANSACRegressor                      9.404825e-01  9.414736e-01  1.338007e+01
# LassoLars                            9.313428e-01  9.324862e-01  1.437074e+01
# Lasso                                9.313339e-01  9.324774e-01  1.437167e+01
# LarsCV                               9.127972e-01  9.142494e-01  1.619575e+01
# KNeighborsRegressor                  9.108588e-01  9.123433e-01  1.637477e+01
# SVR                                  8.949993e-01  8.967479e-01  1.777182e+01
# NuSVR                                8.917172e-01  8.935205e-01  1.804744e+01
# PassiveAggressiveRegressor           8.498942e-01  8.523939e-01  2.124882e+01
# ElasticNet                           8.426075e-01  8.452286e-01  2.175845e+01
# TweedieRegressor                     7.547473e-01  7.588315e-01  2.716082e+01
# GammaRegressor                       7.498300e-01  7.539961e-01  2.743176e+01
# OrthogonalMatchingPursuit            7.215012e-01  7.261391e-01  2.894327e+01
# OrthogonalMatchingPursuitCV          7.215012e-01  7.261391e-01  2.894327e+01
# AdaBoostRegressor                    6.499051e-01  6.557352e-01  3.245106e+01
# DummyRegressor                      -1.760718e-02 -6.608335e-04  5.532559e+01
# QuantileRegressor                   -5.787265e-02 -4.025576e-02  5.640956e+01
# GaussianProcessRegressor            -1.665980e+00 -1.621583e+00  8.954975e+01
# KernelRidge                         -4.133655e+00 -4.048164e+00  1.242651e+02
# Lars                                -6.757546e+17 -6.645012e+17  4.508484e+10
#
#                                Time Taken
# Model
# MLPRegressor                     3.833287
# XGBRegressor                     0.270786
# HistGradientBoostingRegressor    0.527092
# ExtraTreesRegressor              9.901402
# RandomForestRegressor           11.715578
# BaggingRegressor                 1.249456
# DecisionTreeRegressor            0.202371
# ExtraTreeRegressor               0.111679
# PoissonRegressor                 0.029952
# TransformedTargetRegressor       0.029269
# LinearRegression                 0.026487
# RidgeCV                          0.026864
# BayesianRidge                    0.040339
# Ridge                            0.014237
# HuberRegressor                   0.293689
# LinearSVR                        0.282635
# SGDRegressor                     0.110159
# LassoCV                          0.234158
# GradientBoostingRegressor        2.647009
# ElasticNetCV                     0.110366
# LassoLarsCV                      0.071153
# LassoLarsIC                      0.036291
# RANSACRegressor                  0.126606
# LassoLars                        0.016151
# Lasso                            0.023158
# LarsCV                           0.114765
# KNeighborsRegressor              0.182649
# SVR                             11.148602
# NuSVR                           10.802761
# PassiveAggressiveRegressor       0.051663
# ElasticNet                       0.017453
# TweedieRegressor                 0.017358
# GammaRegressor                   0.023910
# OrthogonalMatchingPursuit        0.017973
# OrthogonalMatchingPursuitCV      0.054218
# AdaBoostRegressor                1.380797
# DummyRegressor                   0.012084
# QuantileRegressor                5.261847
# GaussianProcessRegressor       200.036751
# KernelRidge                     13.521033
# Lars                             0.027752

# %%
from sklearn.neural_network import MLPRegressor

# %%
run_model(MLPRegressor())
# Out:
# Train Score:  1.0
# Test Score:  1
# ✅ Model is Fit
# R2 Score: 0.9997
# MSE: 0.8815
# MAE: 0.6493
# RMSE: 0.9389
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
params={
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50), (50, 100)],
    'activation': ['relu', 'tanh', 'logistic'],
    'solver': ['adam', 'sgd', 'lbfgs'],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'power_t': [0.5, 0.7, 0.9],
    'alpha': [0.0001, 0.001, 0.01],}

# %%
cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=21)
grid=GridSearchCV(estimator=MLPRegressor(),scoring='r2', param_grid=params, cv=cv, n_jobs=-1, verbose=2)

# %%
run_model(grid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 run_model(grid)
#
# Cell In[36], line 2, in run_model(model)
#       1 def run_model(model):
# ----> 2     model.fit(X_train_processed,y_train)
#       3     y_pred=model.predict(X_test_processed)
#       4     check_CV(model)
#       5     show_metrics(model,y_pred)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1131, in BaseSearchCV.fit(self, X, y, **params)
#    1128     return results
#    1130 if "callback_ctx" in signature(self._run_search).parameters:
# -> 1131     self._run_search(evaluate_candidates, callback_ctx=root_callback_ctx)
#    1132 else:
#    1133     # custom search classes
#    1134     self._run_search(evaluate_candidates)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1718, in GridSearchCV._run_search(self, evaluate_candidates, callback_ctx)
#    1710 candidate_params = ParameterGrid(self.param_grid)
#    1712 search_ctx = callback_ctx.subcontext(
#    1713     task_name="search",
#    1714     max_subtasks=len(candidate_params) * self.n_splits_,
#    1715     sequential_subtasks=False,
#    1716 ).call_on_fit_task_begin(estimator=self)
# -> 1718 evaluate_candidates(ParameterGrid(self.param_grid), callback_ctx=search_ctx)
#    1720 search_ctx.call_on_fit_task_end(estimator=self)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1048, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results, callback_ctx)
#    1045 n_candidates = len(candidate_params)
#    1046 n_splits = self.n_splits_
# -> 1048 cv_splits = list(cv.split(X, y, **routed_params.splitter.split))
#    1049 if len(cv_splits) != n_splits:
#    1050     raise ValueError(
#    1051         f"cv.split and cv.get_n_splits return inconsistent results. "
#    1052         f"Expected {n_splits} splits, got {len(cv_splits)}"
#    1053     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_split.py:411, in _BaseKFold.split(self, X, y, groups)
#     403 if self.n_splits > n_samples:
#     404     raise ValueError(
#     405         (
#     406             "Cannot have number of splits n_splits={0} greater"
#     407             " than the number of samples: n_samples={1}."
#     408         ).format(self.n_splits, n_samples)
#     409     )
# --> 411 for train, test in super().split(X, y, groups):
#     412     yield train, test
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_split.py:142, in BaseCrossValidator.split(self, X, y, groups)
#     140 X, y, groups = indexable(X, y, groups)
#     141 indices = np.arange(_num_samples(X))
# --> 142 for test_index in self._iter_test_masks(X, y, groups):
#     143     train_index = indices[np.logical_not(test_index)]
#     144     test_index = indices[test_index]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_split.py:845, in StratifiedKFold._iter_test_masks(self, X, y, groups)
#     844 def _iter_test_masks(self, X, y=None, groups=None):
# --> 845     test_folds = self._make_test_folds(X, y)
#     846     for i in range(self.n_splits):
#     847         yield test_folds == i
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/model_selection/_split.py:788, in StratifiedKFold._make_test_folds(self, X, y)
#     786 allowed_target_types = ("binary", "multiclass")
#     787 if type_of_target_y not in allowed_target_types:
# --> 788     raise ValueError(
#     789         "Supported target types are: {}. Got {!r} instead.".format(
#     790             allowed_target_types, type_of_target_y
#     791         )
#     792     )
#     794 y = column_or_1d(y)
#     796 _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
#
# ValueError: Supported target types are: ('binary', 'multiclass'). Got 'continuous' instead.
